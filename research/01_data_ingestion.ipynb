# %%
import os
import sys
print(sys.path)
# Out:
# ['c:\\Users\\Hajri\\anaconda3\\envs\\kidney\\python310.zip', 'c:\\Users\\Hajri\\anaconda3\\envs\\kidney\\DLLs', 'c:\\Users\\Hajri\\anaconda3\\envs\\kidney\\lib', 'c:\\Users\\Hajri\\anaconda3\\envs\\kidney', '', 'C:\\Users\\Hajri\\AppData\\Roaming\\Python\\Python310\\site-packages', 'C:\\Users\\Hajri\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32', 'C:\\Users\\Hajri\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib', 'C:\\Users\\Hajri\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin', 'c:\\Users\\Hajri\\anaconda3\\envs\\kidney\\lib\\site-packages', 'c:\\projects\\kidney-disease-classification\\src']

# %%
# %pwd
# Out:
# 'c:\\Projects\\Kidney-disease-classification\\research'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.CNNClassifier.constants import *
from src.CNNClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = config_file_path,
        params_filepath = params_file_path):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        create_directories([self.config.artifacts_root])



    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion
        
        create_directories([config.root_dir])
        
        data_ingestion_config = DataIngestionConfig(
            root_dir = Path(config.root_dir),
            source_URL = config.source_URL,
            local_data_file = Path(config.local_data_file),
            unzip_dir = Path(config.unzip_dir)
        )
        
        return data_ingestion_config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 3
#       1 from pathlib import Path
#       2 from CNNClassifier.utils.common import read_yaml, create_directories
# ----> 3 from CNNClassifier.entity.config_entity import DataIngestionConfig
#       5 class ConfigurationManager:
#       6     def __init__(self, config_filepath, params_filepath):
#       7         # Convertir les chemins en Path si ce sont des chaînes
#
# ModuleNotFoundError: No module named 'CNNClassifier.entity.config_entity'

# %%
import zipfile
import gdown
from src.CNNClassifier.utils.common import get_size
from src.CNNClassifier.log_config import logging

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config
    
    def download_data(self) -> str:
        try:
            dataset_url = self.config.source_URL
            zip_file_path = self.config.local_data_file
            os.makedirs(self.config.root_dir, exist_ok=True)
            logging.info(f"Downloading file from :[{dataset_url}] into :[{zip_file_path}]")

            file_id = dataset_url.split("/")[-2]
            prefix = "https://drive.google.com/uc?/export=download&id="
            download_url = prefix + file_id
            gdown.download(url=download_url, output=zip_file_path, quiet=False)

            logging.info(f"File downloaded successfully and saved at :[{zip_file_path}]")
        except Exception as e:
            raise e
    def extract_zip_file(self):
        try:
            unzip_path = self.config.unzip_dir

            os.makedirs(unzip_path, exist_ok=True)
            with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
                zip_ref.extractall(unzip_path)
            
        except Exception as e:
            raise e

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    
    print(data_ingestion_config)
    
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_data()
    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 2
#       1 from pathlib import Path
# ----> 2 from configuration import ConfigurationManager
#       3 from data_ingestion import DataIngestion
#       5 try:
#       6     # Initialise la configuration
#
# ModuleNotFoundError: No module named 'configuration'

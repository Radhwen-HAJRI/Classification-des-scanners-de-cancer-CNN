# %%
#config_box
d = {"key":"val","key1":"val1"}

# %%
from box import ConfigBox

# %%
d2 = ConfigBox(d)

# %%
d2.key
# Out:
# 'val'

# %%
## download data from google drive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1qru_Ka_iebQ9tvkJMq3hUhMdQt_fQyI4/view?usp=drive_link"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1qru_Ka_iebQ9tvkJMq3hUhMdQt_fQyI4'

# %%
url = f"https://drive.google.com/uc?id={file_id}"
prefix="https://drive.google.com/uc/export=download&id="
gdown.download(url ,"kidney_CT_scan_data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qru_Ka_iebQ9tvkJMq3hUhMdQt_fQyI4
# To: c:\Projects\Kidney-disease-classification\research\kidney_CT_scan_data.zip
# 100%|██████████| 510/510 [00:00<?, ?B/s]
# 'kidney_CT_scan_data.zip'
